# %% [markdown]
# # TASK 1: Single RUL Regressor for DS08
# (organizing the project by task and notebook)
# - using the data from dev and test sets for DS08 (the dataset that contains all failures)
#     I first tried this with the first set, the dataset that contains only one failure mode, but it didn't have as many units and I ran into issues with splitting the data up. We should revisit this together tho (anything that I do or say we should always go over again together if there is any doubt)
# - build a RUL regressor that predicts the RUL
# ### imports

# %%
import os
import pickle
import h5py
import time
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import gridspec
import scipy.stats as stats
import math
import random
import gc
import multiprocessing as mp

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, InputLayer, Dense, Conv1D, BatchNormalization, Flatten, Dropout
# %matplotlib inline

# %% [markdown]
# ## LOAD the data

# %%
df = pd.read_csv('df08_rul_reg.csv')
df_aux = pd.read_csv('df08_aux_rul_reg.csv')

# drop the first column, alternatively handle it better during saving/loading
df.drop(columns=[df.columns[0]], inplace=True)
df_aux.drop(columns=[df_aux.columns[0]], inplace=True)

# %% [markdown]
# ## LOAD the labels

# %%
y_labels = []
with open("y_labels.txt", "r") as f:
    for l in f:
        y_labels.append(l.strip())
        
t_labels = []
with open("t_labels.txt", "r") as f:
    for l in f:
        t_labels.append(l.strip())
        
print(y_labels)
print(t_labels)
# Out:
# ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod', 'HPC_flow_mod', 'HPT_eff_mod', 'HPT_flow_mod', 'LPT_eff_mod', 'LPT_flow_mod']
# ['alt', 'Mach', 'TRA', 'T2', 'T24', 'T30', 'T48', 'T50', 'P15', 'P2', 'P21', 'P24', 'Ps30', 'P40', 'P50', 'Nf', 'Nc', 'Wf']

# %% [markdown]
# ### Split the set up by flight class

# %%
df1 = df[df.Fc == 1]
df2 = df[df.Fc == 2]
df3 = df[df.Fc == 3]
print(f"Fc1 units: {pd.unique(df1.ui)}")
print(f"Fc2 units: {pd.unique(df2.ui)}")
print(f"Fc3 units: {pd.unique(df3.ui)}")
# Out:
# Fc1 units: [ 0  2  8  9 14]
# Fc2 units: [ 3  4  6  7 10 20 21 22 23 24]
# Fc3 units: [ 1  5 11 12 13 15 16 17 18 19]

# %% [markdown]
# ### Split the set up by train, val, test

# %%
def train_test_split(df, y_labels, t_labels, verbose=False):
    ui = list(pd.unique(df.ui))
    samples = len(ui)
    if verbose:
        print(f"unit unique identifier (ui): {ui}")
        print(f"number of units: {samples}")
    
    train_pct = .65
    val_pct = .2
    test_pct = .15
    train_start = 0
    train_cnt = int(samples*train_pct)
    val_cnt = int(samples*val_pct)
    test_cnt = int(samples*test_pct)+1
    if verbose:
        print(f"train, val, test set counts: {train_cnt}, {val_cnt}, {test_cnt}")
    
    assert train_cnt + val_cnt + test_cnt == samples, "error"

    train_ui = random.sample(ui, train_cnt)
    ui = list(set(ui) - set(train_ui))
    val_ui = random.sample(ui, val_cnt)
    ui = list(set(ui) - set(val_ui))
    test_ui = random.sample(ui, test_cnt)
    ui = list(set(ui) - set(test_ui))
    
    assert len(ui) == 0, "error"
    
    if verbose:
        print(f"train ui: {train_ui}")
        print(f"val ui: {val_ui}")
        print(f"test ui: {test_ui}")
    
    train_df = df[df['ui'].isin(train_ui)]
    val_df = df[df['ui'].isin(val_ui)]
    test_df = df[df['ui'].isin(test_ui)]
    
    train_y = np.array(train_df.y, dtype=np.int32)
    val_y = np.array(val_df.y, dtype=np.int32)
    test_y = np.array(test_df.y, dtype=np.int32)
    
    train_deg = train_df[y_labels]
    val_deg = val_df[y_labels]
    test_deg = test_df[y_labels]
    
    train_df = pd.concat([train_df[t_labels], train_deg], axis=1)
    val_df = pd.concat([val_df[t_labels], val_deg], axis=1)
    test_df = pd.concat([test_df[t_labels], test_deg], axis=1)
    
    return train_df, train_y, val_df, val_y, test_df, test_y

# %% [markdown]
# ### Flight class 1 train, val, test sets

# %%
train1_df, train1_y, val1_df, val1_y, test1_df, test1_y = train_test_split(df1, y_labels, t_labels, verbose=True)
# Out:
# unit unique identifier (ui): [0, 2, 8, 9, 14]
# number of units: 5
# train, val, test set counts: 3, 1, 1
# train ui: [9, 0, 8]
# val ui: [14]
# test ui: [2]

# %% [markdown]
# ### Flight class 2 train, val, test sets

# %%
train2_df, train2_y, val2_df, val2_y, test2_df, test2_y = train_test_split(df2, y_labels, t_labels, verbose=True)
# Out:
# unit unique identifier (ui): [3, 4, 6, 7, 10, 20, 21, 22, 23, 24]
# number of units: 10
# train, val, test set counts: 6, 2, 2
# train ui: [20, 24, 10, 7, 21, 4]
# val ui: [23, 22]
# test ui: [6, 3]

# %% [markdown]
# ### Flight class 3 train, val, test sets

# %%
train3_df, train3_y, val3_df, val3_y, test3_df, test3_y = train_test_split(df3, y_labels, t_labels, verbose=True)
# Out:
# unit unique identifier (ui): [1, 5, 11, 12, 13, 15, 16, 17, 18, 19]
# number of units: 10
# train, val, test set counts: 6, 2, 2
# train ui: [17, 13, 15, 18, 1, 19]
# val ui: [5, 16]
# test ui: [11, 12]

# %% [markdown]
# ### Now we have 3 models to train, one for each flight class

# %% [markdown]
# One dimensional convolutional neural network architecture (1-d CNN). The architecture of the CNN neural network used in this research also comprises five layers (L = 5). The network has three initial convolutional layers with filters of size 10. The first two convolutions have ten channels and the last convolution has only one channel. Zero padding is used to keep the feature map through the network. The resulting 2D feature map is flattened and the network ends with a 50-way fully connected layer followed by a linear output neuron. The network uses ReLu as the activation function. The network has 24k trainable parameters (H). Similarly as for the FNN, the final architecture is the result of conducting a grid-search over the following hyperparameters: number of hidden layers [1-4], number of channels [10, 20, 30] at each convolutional layer, filter size [10, 20], number of neurons at the fully connected layer [50, 100], activation function type [tanh, relu], and window size of the siding window [20, 50, 200].

# %% [markdown]
# mini-batch stochastic gradient discent, batch size = 1024 learning rate .001, 60 epochs for FNN and 30 epochs for CNN, patience of 5 epochs

# %% [markdown]
# ### STEPS
# 1. temporalize
# 2. standardize

# %%
def temporalize_data(inputs, outputs, lookback, horizon, n_features, n_out):
        """
            @brief: reshapes a dataset to account for time

            @params:
                inputs: the 'X' vector (what you are training on)
                outputs: the 'y' vector (what you are predicting)
                lookback: the number of samples in the lookback period (NOTE: not
                            the same as lookback_hours)
                horizon: the number of samples in the horizon period (NOTE: not
                            the same as horizon_hours)
                n_features: the number of features in inputs (X)
                n_out: the number of outputs in outputs (y)

            @returns:
                X_out: a 3d numpy matrix of size [sz, lookback, n_features]
                y: a 3d numpy matrix of size [sz, horizon, n_out]
        """
        X_out = []
        y = []
        ################# the number of samples to generate accounts for the lookback and horizon size
        sz = (len(inputs) - (lookback + horizon) - 1)
        for i in range(0, sz):
            temp = []
            for j in range(0, lookback):
                ################# temp stacks sequential observations and creates a single sample
                temp.append(inputs[[i + j]])
            ################# X_out[0] is now a single sample array with the first [0 - <lookback>] observations
            X_out.append(temp)
            temp = []
            if (len(outputs) > 0):
                ################# the subsequent observations are the values to predict
                for j in range(lookback, lookback + horizon):
                    temp.append(outputs[[i + j]])
                ################# y[0] is now a single sample array with the first [<lookback> - <horizon>] observations
                y.append(temp)
        ################# convert to numpy arrays and reshape for LSTM input
        X_out = np.array(X_out)
        X_out = X_out.reshape(X_out.shape[0], lookback, n_features)
        y = np.array(y)
        y = y.reshape(y.shape[0], horizon, n_out)
        return X_out, y

# %%
# 20 timesteps back
lookback = 20

# 1 timestep forward
horizon = 1

# df columns
n_features = len(train1_df.columns)

# rul
n_out = 1 

# flight class 1
X_train1, y_train1 = temporalize_data(np.array(train1_df), train1_y, lookback, horizon, n_features, n_out)
X_test1, y_test1 = temporalize_data(np.array(test1_df), test1_y, lookback, horizon, n_features, n_out)
X_val1, y_val1 = temporalize_data(np.array(val1_df), val1_y, lookback, horizon, n_features, n_out)

# flight class 2
X_train2, y_train2 = temporalize_data(np.array(train2_df), train2_y, lookback, horizon, n_features, n_out)
X_test2, y_test2 = temporalize_data(np.array(test2_df), test2_y, lookback, horizon, n_features, n_out)
X_val2, y_val2 = temporalize_data(np.array(val2_df), val2_y, lookback, horizon, n_features, n_out)

# flight class 3
X_train3, y_train3 = temporalize_data(np.array(train3_df), train3_y, lookback, horizon, n_features, n_out)
X_test3, y_test3 = temporalize_data(np.array(test3_df), test3_y, lookback, horizon, n_features, n_out)
X_val3, y_val3 = temporalize_data(np.array(val3_df), val3_y, lookback, horizon, n_features, n_out)

# %% [markdown]
# ### Standardize the data

# %%
mu1 = np.mean(X_train1)
std1 = np.std(X_train1)

X_train1 = X_train1 - mu1 / std1
X_test1 = X_test1 - mu1 / std1
X_val1 = X_val1 - mu1 / std1

mu2 = np.mean(X_train2)
std2 = np.std(X_train2)

X_train2 = X_train2 - mu2 / std2
X_test2 = X_test2 - mu2 / std2
X_val2 = X_val2 - mu2 / std2

mu3 = np.mean(X_train3)
std3 = np.std(X_train3)

X_train3 = X_train3 - mu3 / std3
X_test3 = X_test3 - mu3 / std3
X_val3 = X_val3 - mu3 / std3

# %% [markdown]
# ### the shape should now be (num_samples, num_timesteps, num_features)

# %%
X_train1.shape
# Out:
# (96644, 20, 28)

# %%
y_train1.shape
# Out:
# (96644, 1, 1)

# %% [markdown]
# ## BUILD and TRAIN the model

# %%
# early stopping parameters
min_delta = 5
patience = 20

# compile parameters
lr = .00005

# fit parameters
batch_size = 32
epochs = 500

model = Sequential(name='fc1_cnn')
model.add(InputLayer(input_shape=(lookback, n_features), name='input'))

# I standardized above because I wasn't sure how exactly this is working, need to read more how to use it
#model.add(BatchNormalization(name='bn'))
model.add(Conv1D(filters=10, kernel_size=10, strides=1, padding='same', activation='relu', kernel_initializer='glorot_uniform', name='cl1'))
model.add(Conv1D(filters=10, kernel_size=10, strides=1, padding='same', activation='relu', kernel_initializer='glorot_uniform', name='cl2'))
model.add(Conv1D(filters=1, kernel_size=10, strides=1, padding='same', activation='relu', kernel_initializer='glorot_uniform', name='cl3'))
model.add(Flatten(name='l4'))
model.add(Dense(units=50, kernel_initializer='glorot_uniform', activation='relu', name='dl1'))
#model.add(Dropout(rate=.25, name='do1'))
model.add(Dense(units=1, name='output'))


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                               mode='min', 
                                               min_delta=min_delta, 
                                               patience=patience, 
                                               verbose=1,
                                               restore_best_weights=True)

model.compile(loss='mse',
              optimizer=keras.optimizers.Adam(lr=lr),
              metrics=[keras.metrics.RootMeanSquaredError()])

model.summary()

history = model.fit(X_train1, y_train1, 
                    batch_size=batch_size, 
                    epochs=epochs,
                    validation_data=(X_val1, y_val1),
                    callbacks=[early_stopping])


fig = plt.figure(figsize=(9,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("loss")
plt.show()

fig = plt.figure(figsize=(9,6))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title("rmse")
plt.show()
# Out:
# Model: "fc1_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cl1 (Conv1D)                 (None, 20, 10)            2810
# _________________________________________________________________
# cl2 (Conv1D)                 (None, 20, 10)            1010
# _________________________________________________________________
# cl3 (Conv1D)                 (None, 20, 1)             101
# _________________________________________________________________
# l4 (Flatten)                 (None, 20)                0
# _________________________________________________________________
# dl1 (Dense)                  (None, 50)                1050
# _________________________________________________________________
# output (Dense)               (None, 1)                 51
# =================================================================
# Total params: 5,022
# Trainable params: 5,022
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 1511/1511 [==============================] - 6s 4ms/step - loss: 1902.0505 - root_mean_squared_error: 43.6125 - val_loss: 571.9893 - val_root_mean_squared_error: 23.9163
# Epoch 2/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 487.5250 - root_mean_squared_error: 22.0800 - val_loss: 539.0769 - val_root_mean_squared_error: 23.2180
# Epoch 3/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 483.0233 - root_mean_squared_error: 21.9778 - val_loss: 571.2084 - val_root_mean_squared_error: 23.9000
# Epoch 4/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 481.3100 - root_mean_squared_error: 21.9388 - val_loss: 551.0814 - val_root_mean_squared_error: 23.4751
# Epoch 5/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 468.1301 - root_mean_squared_error: 21.6363 - val_loss: 669.5992 - val_root_mean_squared_error: 25.8766
# Epoch 6/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 463.9565 - root_mean_squared_error: 21.5396 - val_loss: 505.0173 - val_root_mean_squared_error: 22.4726
# Epoch 7/500
# 1511/1511 [==============================] - 5s 3ms/step - loss: 460.3071 - root_mean_squared_error: 21.4548 - val_loss: 499.9523 - val_root_mean_squared_error: 22.3596
# Epoch 8/500
# 1511/1511 [==============================] - 5s 3ms/step - loss: 450.3257 - root_mean_squared_error: 21.2209 - val_loss: 518.6282 - val_root_mean_squared_error: 22.7734
# Epoch 9/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 446.5948 - root_mean_squared_error: 21.1328 - val_loss: 466.9637 - val_root_mean_squared_error: 21.6093
# Epoch 10/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 435.0786 - root_mean_squared_error: 20.8585 - val_loss: 556.3282 - val_root_mean_squared_error: 23.5866
# Epoch 11/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 429.8666 - root_mean_squared_error: 20.7332 - val_loss: 643.2181 - val_root_mean_squared_error: 25.3617
# Epoch 12/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 422.8726 - root_mean_squared_error: 20.5639 - val_loss: 461.8170 - val_root_mean_squared_error: 21.4899
# Epoch 13/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 413.4911 - root_mean_squared_error: 20.3345 - val_loss: 429.1209 - val_root_mean_squared_error: 20.7152
# Epoch 14/500
# 1511/1511 [==============================] - 6s 4ms/step - loss: 402.6529 - root_mean_squared_error: 20.0662 - val_loss: 556.8094 - val_root_mean_squared_error: 23.5968
# Epoch 15/500
# 1511/1511 [==============================] - 6s 4ms/step - loss: 396.1129 - root_mean_squared_error: 19.9026 - val_loss: 650.8292 - val_root_mean_squared_error: 25.5114
# Epoch 16/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 384.6477 - root_mean_squared_error: 19.6124 - val_loss: 390.2649 - val_root_mean_squared_error: 19.7551
# Epoch 17/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 374.5793 - root_mean_squared_error: 19.3541 - val_loss: 412.0906 - val_root_mean_squared_error: 20.3000
# Epoch 18/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 365.4978 - root_mean_squared_error: 19.1180 - val_loss: 355.5620 - val_root_mean_squared_error: 18.8564
# Epoch 19/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 354.5477 - root_mean_squared_error: 18.8294 - val_loss: 333.1285 - val_root_mean_squared_error: 18.2518
# Epoch 20/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 345.2869 - root_mean_squared_error: 18.5819 - val_loss: 380.3658 - val_root_mean_squared_error: 19.5030
# Epoch 21/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 339.9190 - root_mean_squared_error: 18.4369 - val_loss: 435.9725 - val_root_mean_squared_error: 20.8800
# Epoch 22/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 328.6005 - root_mean_squared_error: 18.1273 - val_loss: 460.4003 - val_root_mean_squared_error: 21.4569
# Epoch 23/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 331.4152 - root_mean_squared_error: 18.2048 - val_loss: 319.9842 - val_root_mean_squared_error: 17.8881
# Epoch 24/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 322.1542 - root_mean_squared_error: 17.9487 - val_loss: 276.9710 - val_root_mean_squared_error: 16.6424
# Epoch 25/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 319.6987 - root_mean_squared_error: 17.8801 - val_loss: 277.2033 - val_root_mean_squared_error: 16.6494
# Epoch 26/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 317.8063 - root_mean_squared_error: 17.8271 - val_loss: 271.7896 - val_root_mean_squared_error: 16.4860
# Epoch 27/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 319.5533 - root_mean_squared_error: 17.8761 - val_loss: 252.0952 - val_root_mean_squared_error: 15.8775
# Epoch 28/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 317.5515 - root_mean_squared_error: 17.8200 - val_loss: 726.4962 - val_root_mean_squared_error: 26.9536
# Epoch 29/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 317.4512 - root_mean_squared_error: 17.8172 - val_loss: 291.5272 - val_root_mean_squared_error: 17.0742
# Epoch 30/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 310.7255 - root_mean_squared_error: 17.6274 - val_loss: 253.4093 - val_root_mean_squared_error: 15.9188
# Epoch 31/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 313.9895 - root_mean_squared_error: 17.7197 - val_loss: 247.8533 - val_root_mean_squared_error: 15.7434
# Epoch 32/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 310.3134 - root_mean_squared_error: 17.6157 - val_loss: 405.0950 - val_root_mean_squared_error: 20.1270
# Epoch 33/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 305.6089 - root_mean_squared_error: 17.4817 - val_loss: 532.9240 - val_root_mean_squared_error: 23.0851
# Epoch 34/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 311.1929 - root_mean_squared_error: 17.6407 - val_loss: 280.7368 - val_root_mean_squared_error: 16.7552
# Epoch 35/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 302.7677 - root_mean_squared_error: 17.4002 - val_loss: 497.9929 - val_root_mean_squared_error: 22.3158
# Epoch 36/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 306.2269 - root_mean_squared_error: 17.4993 - val_loss: 275.1096 - val_root_mean_squared_error: 16.5864
# Epoch 37/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 301.5876 - root_mean_squared_error: 17.3663 - val_loss: 475.0243 - val_root_mean_squared_error: 21.7951
# Epoch 38/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 298.7911 - root_mean_squared_error: 17.2856 - val_loss: 351.6177 - val_root_mean_squared_error: 18.7515
# Epoch 39/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 297.1908 - root_mean_squared_error: 17.2392 - val_loss: 296.8597 - val_root_mean_squared_error: 17.2296
# Epoch 40/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 297.0580 - root_mean_squared_error: 17.2354 - val_loss: 696.2069 - val_root_mean_squared_error: 26.3857
# Epoch 41/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 298.1873 - root_mean_squared_error: 17.2681 - val_loss: 227.8796 - val_root_mean_squared_error: 15.0957
# Epoch 42/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 296.9286 - root_mean_squared_error: 17.2316 - val_loss: 228.0731 - val_root_mean_squared_error: 15.1021
# Epoch 43/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 299.5103 - root_mean_squared_error: 17.3064 - val_loss: 405.3348 - val_root_mean_squared_error: 20.1329
# Epoch 44/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 295.2423 - root_mean_squared_error: 17.1826 - val_loss: 287.6747 - val_root_mean_squared_error: 16.9610
# Epoch 45/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 296.8559 - root_mean_squared_error: 17.2295 - val_loss: 262.4524 - val_root_mean_squared_error: 16.2004
# Epoch 46/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 293.9749 - root_mean_squared_error: 17.1457 - val_loss: 215.2307 - val_root_mean_squared_error: 14.6707
# Epoch 47/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 292.3890 - root_mean_squared_error: 17.0994 - val_loss: 462.3481 - val_root_mean_squared_error: 21.5023
# Epoch 48/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 290.4869 - root_mean_squared_error: 17.0437 - val_loss: 214.5928 - val_root_mean_squared_error: 14.6490
# Epoch 49/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 291.8846 - root_mean_squared_error: 17.0846 - val_loss: 435.7498 - val_root_mean_squared_error: 20.8746
# Epoch 50/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 291.4328 - root_mean_squared_error: 17.0714 - val_loss: 411.3094 - val_root_mean_squared_error: 20.2808
# Epoch 51/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 286.7478 - root_mean_squared_error: 16.9336 - val_loss: 289.9246 - val_root_mean_squared_error: 17.0272
# Epoch 52/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 289.1270 - root_mean_squared_error: 17.0037 - val_loss: 320.5687 - val_root_mean_squared_error: 17.9044
# Epoch 53/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 282.9940 - root_mean_squared_error: 16.8224 - val_loss: 292.8748 - val_root_mean_squared_error: 17.1136
# Epoch 54/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 287.0487 - root_mean_squared_error: 16.9425 - val_loss: 217.8954 - val_root_mean_squared_error: 14.7613
# Epoch 55/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 285.3263 - root_mean_squared_error: 16.8916 - val_loss: 315.8119 - val_root_mean_squared_error: 17.7711
# Epoch 56/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 284.8237 - root_mean_squared_error: 16.8767 - val_loss: 245.0059 - val_root_mean_squared_error: 15.6527
# Epoch 57/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 288.5557 - root_mean_squared_error: 16.9869 - val_loss: 308.8281 - val_root_mean_squared_error: 17.5735
# Epoch 58/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 286.8927 - root_mean_squared_error: 16.9379 - val_loss: 901.7447 - val_root_mean_squared_error: 30.0291
# Epoch 59/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 285.6115 - root_mean_squared_error: 16.9000 - val_loss: 223.9944 - val_root_mean_squared_error: 14.9664
# Epoch 60/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 285.7992 - root_mean_squared_error: 16.9056 - val_loss: 209.4216 - val_root_mean_squared_error: 14.4714
# Epoch 61/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 277.2926 - root_mean_squared_error: 16.6521 - val_loss: 214.1846 - val_root_mean_squared_error: 14.6350
# Epoch 62/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 278.3746 - root_mean_squared_error: 16.6846 - val_loss: 242.6375 - val_root_mean_squared_error: 15.5768
# Epoch 63/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 277.9182 - root_mean_squared_error: 16.6709 - val_loss: 404.4006 - val_root_mean_squared_error: 20.1097
# Epoch 64/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 278.2775 - root_mean_squared_error: 16.6817 - val_loss: 562.1097 - val_root_mean_squared_error: 23.7089
# Epoch 65/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 277.7403 - root_mean_squared_error: 16.6655 - val_loss: 317.4617 - val_root_mean_squared_error: 17.8175
# Epoch 66/500
# 1511/1511 [==============================] - 6s 4ms/step - loss: 271.2824 - root_mean_squared_error: 16.4707 - val_loss: 384.9172 - val_root_mean_squared_error: 19.6193
# Epoch 67/500
# 1511/1511 [==============================] - 5s 3ms/step - loss: 274.1362 - root_mean_squared_error: 16.5571 - val_loss: 190.7412 - val_root_mean_squared_error: 13.8109
# Epoch 68/500
# 1511/1511 [==============================] - 5s 3ms/step - loss: 279.5344 - root_mean_squared_error: 16.7193 - val_loss: 204.6449 - val_root_mean_squared_error: 14.3054
# Epoch 69/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 277.3424 - root_mean_squared_error: 16.6536 - val_loss: 211.0462 - val_root_mean_squared_error: 14.5274
# Epoch 70/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 269.9845 - root_mean_squared_error: 16.4312 - val_loss: 225.6162 - val_root_mean_squared_error: 15.0205
# Epoch 71/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 270.5216 - root_mean_squared_error: 16.4475 - val_loss: 255.8698 - val_root_mean_squared_error: 15.9959
# Epoch 72/500
# 1511/1511 [==============================] - 5s 3ms/step - loss: 266.1293 - root_mean_squared_error: 16.3135 - val_loss: 190.8813 - val_root_mean_squared_error: 13.8160
# Epoch 73/500
# 1511/1511 [==============================] - 5s 3ms/step - loss: 267.1850 - root_mean_squared_error: 16.3458 - val_loss: 247.0014 - val_root_mean_squared_error: 15.7163
# Epoch 74/500
# 1511/1511 [==============================] - 6s 4ms/step - loss: 270.2787 - root_mean_squared_error: 16.4402 - val_loss: 291.7663 - val_root_mean_squared_error: 17.0812
# Epoch 75/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 261.6141 - root_mean_squared_error: 16.1745 - val_loss: 251.4625 - val_root_mean_squared_error: 15.8576
# Epoch 76/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 263.4536 - root_mean_squared_error: 16.2313 - val_loss: 482.9447 - val_root_mean_squared_error: 21.9760
# Epoch 77/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 262.9146 - root_mean_squared_error: 16.2146 - val_loss: 640.8882 - val_root_mean_squared_error: 25.3158
# Epoch 78/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 267.0832 - root_mean_squared_error: 16.3427 - val_loss: 175.4828 - val_root_mean_squared_error: 13.2470
# Epoch 79/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 260.7827 - root_mean_squared_error: 16.1488 - val_loss: 191.3638 - val_root_mean_squared_error: 13.8334
# Epoch 80/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 256.3593 - root_mean_squared_error: 16.0112 - val_loss: 219.7707 - val_root_mean_squared_error: 14.8247
# Epoch 81/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 258.7841 - root_mean_squared_error: 16.0868 - val_loss: 204.6804 - val_root_mean_squared_error: 14.3067
# Epoch 82/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 254.0409 - root_mean_squared_error: 15.9387 - val_loss: 536.4403 - val_root_mean_squared_error: 23.1612
# Epoch 83/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 254.8808 - root_mean_squared_error: 15.9650 - val_loss: 163.7064 - val_root_mean_squared_error: 12.7948
# Epoch 84/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 258.5635 - root_mean_squared_error: 16.0799 - val_loss: 343.2468 - val_root_mean_squared_error: 18.5269
# Epoch 85/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 254.5505 - root_mean_squared_error: 15.9546 - val_loss: 424.6236 - val_root_mean_squared_error: 20.6064
# Epoch 86/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 255.7112 - root_mean_squared_error: 15.9910 - val_loss: 149.9787 - val_root_mean_squared_error: 12.2466
# Epoch 87/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 253.4039 - root_mean_squared_error: 15.9187 - val_loss: 175.9128 - val_root_mean_squared_error: 13.2632
# Epoch 88/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 245.6795 - root_mean_squared_error: 15.6742 - val_loss: 641.7684 - val_root_mean_squared_error: 25.3331
# Epoch 89/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 247.9034 - root_mean_squared_error: 15.7449 - val_loss: 165.1700 - val_root_mean_squared_error: 12.8518
# Epoch 90/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 249.7334 - root_mean_squared_error: 15.8030 - val_loss: 243.6576 - val_root_mean_squared_error: 15.6095
# Epoch 91/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 243.4091 - root_mean_squared_error: 15.6016 - val_loss: 144.8112 - val_root_mean_squared_error: 12.0338
# Epoch 92/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 242.7487 - root_mean_squared_error: 15.5804 - val_loss: 512.0640 - val_root_mean_squared_error: 22.6288
# Epoch 93/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 249.1154 - root_mean_squared_error: 15.7834 - val_loss: 186.1597 - val_root_mean_squared_error: 13.6440
# Epoch 94/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 240.7371 - root_mean_squared_error: 15.5157 - val_loss: 239.5395 - val_root_mean_squared_error: 15.4771
# Epoch 95/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 243.4538 - root_mean_squared_error: 15.6030 - val_loss: 198.9308 - val_root_mean_squared_error: 14.1043
# Epoch 96/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 238.9188 - root_mean_squared_error: 15.4570 - val_loss: 191.9317 - val_root_mean_squared_error: 13.8539
# Epoch 97/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 234.9323 - root_mean_squared_error: 15.3275 - val_loss: 445.4540 - val_root_mean_squared_error: 21.1058
# Epoch 98/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 233.1747 - root_mean_squared_error: 15.2701 - val_loss: 272.2692 - val_root_mean_squared_error: 16.5006
# Epoch 99/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 235.9180 - root_mean_squared_error: 15.3596 - val_loss: 126.0685 - val_root_mean_squared_error: 11.2280
# Epoch 100/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 233.2752 - root_mean_squared_error: 15.2734 - val_loss: 646.2538 - val_root_mean_squared_error: 25.4215
# Epoch 101/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 233.4886 - root_mean_squared_error: 15.2803 - val_loss: 129.0800 - val_root_mean_squared_error: 11.3613
# Epoch 102/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 230.4028 - root_mean_squared_error: 15.1790 - val_loss: 337.6148 - val_root_mean_squared_error: 18.3743
# Epoch 103/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 229.7189 - root_mean_squared_error: 15.1565 - val_loss: 189.0231 - val_root_mean_squared_error: 13.7486
# Epoch 104/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 229.5544 - root_mean_squared_error: 15.1511 - val_loss: 494.4683 - val_root_mean_squared_error: 22.2366
# Epoch 105/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 225.7783 - root_mean_squared_error: 15.0259 - val_loss: 344.7056 - val_root_mean_squared_error: 18.5662
# Epoch 106/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 224.8392 - root_mean_squared_error: 14.9946 - val_loss: 333.8820 - val_root_mean_squared_error: 18.2724
# Epoch 107/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 227.1852 - root_mean_squared_error: 15.0727 - val_loss: 179.5622 - val_root_mean_squared_error: 13.4001
# Epoch 108/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 226.9074 - root_mean_squared_error: 15.0634 - val_loss: 206.0477 - val_root_mean_squared_error: 14.3544
# Epoch 109/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 221.3900 - root_mean_squared_error: 14.8792 - val_loss: 221.2052 - val_root_mean_squared_error: 14.8730
# Epoch 110/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 219.0679 - root_mean_squared_error: 14.8009 - val_loss: 135.5905 - val_root_mean_squared_error: 11.6443
# Epoch 111/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 216.2040 - root_mean_squared_error: 14.7039 - val_loss: 635.1919 - val_root_mean_squared_error: 25.2030
# Epoch 112/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 217.3155 - root_mean_squared_error: 14.7416 - val_loss: 126.6087 - val_root_mean_squared_error: 11.2521
# Epoch 113/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 223.9932 - root_mean_squared_error: 14.9664 - val_loss: 124.3288 - val_root_mean_squared_error: 11.1503
# Epoch 114/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 215.0417 - root_mean_squared_error: 14.6643 - val_loss: 218.5786 - val_root_mean_squared_error: 14.7844
# Epoch 115/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 211.9578 - root_mean_squared_error: 14.5588 - val_loss: 119.2255 - val_root_mean_squared_error: 10.9190
# Epoch 116/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 211.1380 - root_mean_squared_error: 14.5306 - val_loss: 127.5159 - val_root_mean_squared_error: 11.2923
# Epoch 117/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 209.9752 - root_mean_squared_error: 14.4905 - val_loss: 264.8215 - val_root_mean_squared_error: 16.2733
# Epoch 118/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 208.2137 - root_mean_squared_error: 14.4296 - val_loss: 190.1957 - val_root_mean_squared_error: 13.7911
# Epoch 119/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 210.6827 - root_mean_squared_error: 14.5149 - val_loss: 205.5726 - val_root_mean_squared_error: 14.3378
# Epoch 120/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 203.2010 - root_mean_squared_error: 14.2549 - val_loss: 692.4705 - val_root_mean_squared_error: 26.3148
# Epoch 121/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 206.9576 - root_mean_squared_error: 14.3860 - val_loss: 163.4792 - val_root_mean_squared_error: 12.7859
# Epoch 122/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 204.6629 - root_mean_squared_error: 14.3060 - val_loss: 109.2706 - val_root_mean_squared_error: 10.4533
# Epoch 123/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 201.4081 - root_mean_squared_error: 14.1918 - val_loss: 274.9985 - val_root_mean_squared_error: 16.5831
# Epoch 124/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 202.7380 - root_mean_squared_error: 14.2386 - val_loss: 282.2972 - val_root_mean_squared_error: 16.8017
# Epoch 125/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 204.9209 - root_mean_squared_error: 14.3151 - val_loss: 711.7471 - val_root_mean_squared_error: 26.6786
# Epoch 126/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 197.3404 - root_mean_squared_error: 14.0478 - val_loss: 161.8423 - val_root_mean_squared_error: 12.7217
# Epoch 127/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 196.3551 - root_mean_squared_error: 14.0127 - val_loss: 111.1013 - val_root_mean_squared_error: 10.5405
# Epoch 128/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 196.4211 - root_mean_squared_error: 14.0150 - val_loss: 553.4976 - val_root_mean_squared_error: 23.5265
# Epoch 129/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 200.9976 - root_mean_squared_error: 14.1774 - val_loss: 481.8981 - val_root_mean_squared_error: 21.9522
# Epoch 130/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 195.7180 - root_mean_squared_error: 13.9899 - val_loss: 151.6700 - val_root_mean_squared_error: 12.3154
# Epoch 131/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 188.5623 - root_mean_squared_error: 13.7318 - val_loss: 188.2325 - val_root_mean_squared_error: 13.7198
# Epoch 132/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 194.1310 - root_mean_squared_error: 13.9331 - val_loss: 100.5706 - val_root_mean_squared_error: 10.0285
# Epoch 133/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 188.1371 - root_mean_squared_error: 13.7163 - val_loss: 628.4067 - val_root_mean_squared_error: 25.0680
# Epoch 134/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 188.5345 - root_mean_squared_error: 13.7308 - val_loss: 730.1287 - val_root_mean_squared_error: 27.0209
# Epoch 135/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 183.5047 - root_mean_squared_error: 13.5464 - val_loss: 141.0943 - val_root_mean_squared_error: 11.8783
# Epoch 136/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 188.6869 - root_mean_squared_error: 13.7363 - val_loss: 201.8455 - val_root_mean_squared_error: 14.2072
# Epoch 137/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 187.1608 - root_mean_squared_error: 13.6807 - val_loss: 413.1853 - val_root_mean_squared_error: 20.3270
# Epoch 138/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 194.8195 - root_mean_squared_error: 13.9578 - val_loss: 424.1297 - val_root_mean_squared_error: 20.5944
# Epoch 139/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 182.7327 - root_mean_squared_error: 13.5179 - val_loss: 221.9726 - val_root_mean_squared_error: 14.8987
# Epoch 140/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 179.4343 - root_mean_squared_error: 13.3953 - val_loss: 174.4703 - val_root_mean_squared_error: 13.2087
# Epoch 141/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 183.7387 - root_mean_squared_error: 13.5550 - val_loss: 197.3898 - val_root_mean_squared_error: 14.0495
# Epoch 142/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 183.7893 - root_mean_squared_error: 13.5569 - val_loss: 143.8027 - val_root_mean_squared_error: 11.9918
# Epoch 143/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 175.5752 - root_mean_squared_error: 13.2505 - val_loss: 133.2052 - val_root_mean_squared_error: 11.5415
# Epoch 144/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 181.2260 - root_mean_squared_error: 13.4620 - val_loss: 158.8070 - val_root_mean_squared_error: 12.6019
# Epoch 145/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 176.2912 - root_mean_squared_error: 13.2775 - val_loss: 154.7108 - val_root_mean_squared_error: 12.4383
# Epoch 146/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 171.1263 - root_mean_squared_error: 13.0815 - val_loss: 240.9230 - val_root_mean_squared_error: 15.5217
# Epoch 147/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 176.8581 - root_mean_squared_error: 13.2988 - val_loss: 146.4088 - val_root_mean_squared_error: 12.1000
# Epoch 148/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 170.7794 - root_mean_squared_error: 13.0683 - val_loss: 70.8346 - val_root_mean_squared_error: 8.4163
# Epoch 149/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 173.3421 - root_mean_squared_error: 13.1659 - val_loss: 556.3796 - val_root_mean_squared_error: 23.5877
# Epoch 150/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 175.9055 - root_mean_squared_error: 13.2629 - val_loss: 112.0445 - val_root_mean_squared_error: 10.5851
# Epoch 151/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 176.3161 - root_mean_squared_error: 13.2784 - val_loss: 178.0452 - val_root_mean_squared_error: 13.3434
# Epoch 152/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 174.0190 - root_mean_squared_error: 13.1916 - val_loss: 121.7177 - val_root_mean_squared_error: 11.0326
# Epoch 153/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 169.7707 - root_mean_squared_error: 13.0296 - val_loss: 73.2728 - val_root_mean_squared_error: 8.5599
# Epoch 154/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 169.9977 - root_mean_squared_error: 13.0383 - val_loss: 427.1150 - val_root_mean_squared_error: 20.6668
# Epoch 155/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 166.4920 - root_mean_squared_error: 12.9032 - val_loss: 139.8748 - val_root_mean_squared_error: 11.8269
# Epoch 156/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 170.0256 - root_mean_squared_error: 13.0394 - val_loss: 149.3328 - val_root_mean_squared_error: 12.2202
# Epoch 157/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 174.4606 - root_mean_squared_error: 13.2084 - val_loss: 533.4098 - val_root_mean_squared_error: 23.0957
# Epoch 158/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 165.4792 - root_mean_squared_error: 12.8639 - val_loss: 83.3539 - val_root_mean_squared_error: 9.1298
# Epoch 159/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 166.7753 - root_mean_squared_error: 12.9142 - val_loss: 187.7792 - val_root_mean_squared_error: 13.7033
# Epoch 160/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 169.3553 - root_mean_squared_error: 13.0137 - val_loss: 411.3615 - val_root_mean_squared_error: 20.2820
# Epoch 161/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 163.4088 - root_mean_squared_error: 12.7831 - val_loss: 82.5565 - val_root_mean_squared_error: 9.0861
# Epoch 162/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 163.0842 - root_mean_squared_error: 12.7704 - val_loss: 447.0113 - val_root_mean_squared_error: 21.1426
# Epoch 163/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 171.2004 - root_mean_squared_error: 13.0844 - val_loss: 786.3359 - val_root_mean_squared_error: 28.0417
# Epoch 164/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 163.3212 - root_mean_squared_error: 12.7797 - val_loss: 466.5721 - val_root_mean_squared_error: 21.6003
# Epoch 165/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 166.1028 - root_mean_squared_error: 12.8881 - val_loss: 157.3180 - val_root_mean_squared_error: 12.5426
# Epoch 166/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 158.5889 - root_mean_squared_error: 12.5932 - val_loss: 490.4515 - val_root_mean_squared_error: 22.1461
# Epoch 167/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 158.4651 - root_mean_squared_error: 12.5883 - val_loss: 642.2416 - val_root_mean_squared_error: 25.3425
# Epoch 168/500
# 1511/1511 [==============================] - 5s 4ms/step - loss: 173.9592 - root_mean_squared_error: 13.1894 - val_loss: 77.3446 - val_root_mean_squared_error: 8.7946

# %% [markdown]
# ## EVALUATE the model

# %%
model.evaluate(X_test1, y_test1, batch_size=32, verbose=1)
# Out:
# 1250/1250 [==============================] - 2s 2ms/step - loss: 268.3705 - root_mean_squared_error: 16.3820
# [268.3705139160156, 16.382017135620117]

# %%
y_pred = model.predict(X_test1)

# %%
fig = plt.figure
plt.plot(y_test1.reshape(-1,1), label='true')
plt.plot(y_pred, label='pred')
plt.title("test results")
plt.xlabel("sample number")
plt.ylabel("rul")
plt.show()

# %% [markdown]
# How to map the results back to unit and cycle when this information is lost during training?

# %%
plt.plot(test1_y)
plt.show()

# %%
y_pred.shape

# %% [markdown]
# ### Monday work
# - implement custom CNN model with functional api
# - add batch normalization
# - previous model had "jumpy" loss due to small batch size and high batch-to-batch variance - how to address?

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.datasets import mnist, cifar10
import numpy as np
import pandas as pd

print(tf.__version__)
gpu = tf.config.list_physical_devices('GPU')
has_gpu = gpu[0][0].split(':')[1] == 'GPU'
print(f"[INFO] GPU?: <{has_gpu}> {gpu}")
if(has_gpu):
    tf.config.experimental.set_memory_growth(gpu[0], True)
# Out:
# 2.5.0
# [INFO] GPU?: <True> [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def make_model():
    inputs = keras.Input(shape=(lookback, n_features), name='in1')
    
    x = layers.Conv1D(filters=n_features, kernel_size=5, strides=1, padding='same', kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(.01))(inputs)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    
    x = layers.Conv1D(filters=n_features, kernel_size=3, strides=1, padding='same', kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(.01))(x)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    
    x = layers.Conv1D(filters=1, kernel_size=3, strides=1, padding='same', kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(.01))(x)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    
    x = layers.Flatten()(x)
    
    x = layers.Dense(units=64, activation='relu', kernel_regularizer=regularizers.l2(.01))(x)
    
    #x = layers.Dropout(rate=.2)(x)
    
    outputs = layers.Dense(1)(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    
    return model

model = make_model()
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# in1 (InputLayer)             [(None, 20, 28)]          0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 20, 28)            3948
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 20, 28)            2380
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_16 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 20, 1)             85
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 20, 1)             4
# _________________________________________________________________
# tf.nn.relu_17 (TFOpLambda)   (None, 20, 1)             0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                1344
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 8,050
# Trainable params: 7,936
# Non-trainable params: 114
# _________________________________________________________________

# %% [markdown]
# # flight class 1

# %%
# early stopping parameters
#min_delta = 8
min_delta = 24
patience = 32

# compile parameters
#lr = .00005
lr = .00001

# fit parameters
batch_size = 256
epochs = 1000


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                               mode='min', 
                                               min_delta=min_delta, 
                                               patience=patience, 
                                               verbose=1,
                                               restore_best_weights=True)

model = make_model()

model.compile(loss='mse',
              optimizer=keras.optimizers.Adam(lr=lr),
              metrics=[keras.metrics.RootMeanSquaredError()])

model.summary()

history = model.fit(X_train1, y_train1, 
                    batch_size=batch_size, 
                    epochs=epochs,
                    validation_data=(X_val1, y_val1),
                    callbacks=[early_stopping])


fig = plt.figure(figsize=(9,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("loss")
plt.show()

fig = plt.figure(figsize=(9,6))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title("rmse")
plt.show()

model.evaluate(X_test1, y_test1, batch_size=32, verbose=1)

y_pred = model.predict(X_test1)

fig = plt.figure
plt.plot(y_test1.reshape(-1,1), label='true')
plt.plot(y_pred, label='pred')
plt.title("test results")
plt.xlabel("sample number")
plt.ylabel("rul")
plt.show()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# in1 (InputLayer)             [(None, 20, 28)]          0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 20, 28)            3948
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_21 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 20, 28)            2380
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_22 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 20, 1)             85
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 20, 1)             4
# _________________________________________________________________
# tf.nn.relu_23 (TFOpLambda)   (None, 20, 1)             0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                1344
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 8,050
# Trainable params: 7,936
# Non-trainable params: 114
# _________________________________________________________________
# Epoch 1/1000
# 414/414 [==============================] - 4s 8ms/step - loss: 2241.0039 - root_mean_squared_error: 47.3298 - val_loss: 1588.3835 - val_root_mean_squared_error: 39.8434
# Epoch 2/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2192.7319 - root_mean_squared_error: 46.8172 - val_loss: 1555.6774 - val_root_mean_squared_error: 39.4309
# Epoch 3/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2160.9492 - root_mean_squared_error: 46.4766 - val_loss: 1532.6405 - val_root_mean_squared_error: 39.1379
# Epoch 4/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2130.6401 - root_mean_squared_error: 46.1495 - val_loss: 1507.1281 - val_root_mean_squared_error: 38.8107
# Epoch 5/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2100.2751 - root_mean_squared_error: 45.8195 - val_loss: 1477.6367 - val_root_mean_squared_error: 38.4290
# Epoch 6/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2071.4333 - root_mean_squared_error: 45.5037 - val_loss: 1449.6215 - val_root_mean_squared_error: 38.0628
# Epoch 7/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2043.4020 - root_mean_squared_error: 45.1947 - val_loss: 1428.4536 - val_root_mean_squared_error: 37.7839
# Epoch 8/1000
# 414/414 [==============================] - 3s 8ms/step - loss: 2015.5402 - root_mean_squared_error: 44.8855 - val_loss: 1404.9707 - val_root_mean_squared_error: 37.4719
# Epoch 9/1000
# Epoch 94/1000
# 414/414 [==============================] - 3s 7ms/step - loss: 140.2158 - root_mean_squared_error: 11.7965 - val_loss: 556.9821 - val_root_mean_squared_error: 23.5780
# Epoch 95/1000
# 414/414 [==============================] - 3s 7ms/step - loss: 138.8345 - root_mean_squared_error: 11.7378 - val_loss: 1263.3525 - val_root_mean_squared_error: 35.5288
# Epoch 96/1000
# 414/414 [==============================] - 3s 7ms/step - loss: 138.8730 - root_mean_squared_error: 11.7394 - val_loss: 1546.2609 - val_root_mean_squared_error: 39.3090
# Epoch 97/1000
# 414/414 [==============================] - 3s 7ms/step - loss: 137.6999 - root_mean_squared_error: 11.6893 - val_loss: 1469.3621 - val_root_mean_squared_error: 38.3184
# Epoch 98/1000
# 414/414 [==============================] - 3s 7ms/step - loss: 137.3273 - root_mean_squared_error: 11.6733 - val_loss: 1246.8518 - val_root_mean_squared_error: 35.2958
# Restoring model weights from the end of the best epoch.
# Epoch 00098: early stopping
# 1064/1064 [==============================] - 2s 2ms/step - loss: 174.6475 - root_mean_squared_error: 13.1759

# %% [markdown]
# # Flight class 2

# %%
# early stopping parameters
min_delta = 8
#min_delta = 
patience = 24

# compile parameters
#lr = .00005
lr = .000025

# fit parameters
batch_size = 64
epochs = 500


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                               mode='min', 
                                               min_delta=min_delta, 
                                               patience=patience, 
                                               verbose=1,
                                               restore_best_weights=True)

model = make_model()

model.compile(loss='mse',
              optimizer=keras.optimizers.Adam(lr=lr),
              metrics=[keras.metrics.RootMeanSquaredError()])

model.summary()

history = model.fit(X_train2, y_train2, 
                    batch_size=batch_size, 
                    epochs=epochs,
                    validation_data=(X_val2, y_val2),
                    callbacks=[early_stopping])


fig = plt.figure(figsize=(9,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("loss")
plt.show()

fig = plt.figure(figsize=(9,6))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title("rmse")
plt.show()

model.evaluate(X_test2, y_test2, batch_size=32, verbose=1)

y_pred = model.predict(X_test2)

fig = plt.figure
plt.plot(y_test2.reshape(-1,1), label='true')
plt.plot(y_pred, label='pred')
plt.title("test results for flight class 2")
plt.xlabel("sample number")
plt.ylabel("rul")
plt.show()
# Out:
# C:\Users\lab\envs\tf2gpu\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# in1 (InputLayer)             [(None, 20, 28)]          0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 20, 28)            3948
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_24 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 20, 28)            2380
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_25 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 20, 1)             85
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 20, 1)             4
# _________________________________________________________________
# tf.nn.relu_26 (TFOpLambda)   (None, 20, 1)             0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                1344
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 8,050
# Trainable params: 7,936
# Non-trainable params: 114
# _________________________________________________________________
# Epoch 1/500
# 4947/4947 [==============================] - 37s 7ms/step - loss: 784.1518 - root_mean_squared_error: 27.9891 - val_loss: 469.2340 - val_root_mean_squared_error: 21.6446
# Epoch 2/500
# 4947/4947 [==============================] - 37s 8ms/step - loss: 174.5304 - root_mean_squared_error: 13.1801 - val_loss: 271.6586 - val_root_mean_squared_error: 16.4563
# Epoch 3/500
# 4947/4947 [==============================] - 37s 7ms/step - loss: 96.5615 - root_mean_squared_error: 9.7830 - val_loss: 171.5898 - val_root_mean_squared_error: 13.0663
# Epoch 4/500
# 4947/4947 [==============================] - 38s 8ms/step - loss: 86.1603 - root_mean_squared_error: 9.2357 - val_loss: 62.4676 - val_root_mean_squared_error: 7.8487
# Epoch 5/500
# 4947/4947 [==============================] - 37s 8ms/step - loss: 82.0317 - root_mean_squared_error: 9.0091 - val_loss: 169.6057 - val_root_mean_squared_error: 12.9899
# Epoch 6/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 78.0974 - root_mean_squared_error: 8.7879 - val_loss: 315.9608 - val_root_mean_squared_error: 17.7507
# Epoch 7/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 75.6788 - root_mean_squared_error: 8.6490 - val_loss: 576.7839 - val_root_mean_squared_error: 23.9981
# Epoch 8/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 73.9740 - root_mean_squared_error: 8.5498 - val_loss: 184.7093 - val_root_mean_squared_error: 13.5585
# Epoch 9/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 72.6776 - root_mean_squared_error: 8.4736 - val_loss: 714.3529 - val_root_mean_squared_error: 26.7110
# Epoch 10/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 70.8672 - root_mean_squared_error: 8.3660 - val_loss: 67.1815 - val_root_mean_squared_error: 8.1428
# Epoch 11/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 69.5385 - root_mean_squared_error: 8.2862 - val_loss: 149.6327 - val_root_mean_squared_error: 12.1965
# Epoch 12/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 68.6444 - root_mean_squared_error: 8.2321 - val_loss: 46.0691 - val_root_mean_squared_error: 6.7225
# Epoch 13/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 68.1050 - root_mean_squared_error: 8.1992 - val_loss: 153.9525 - val_root_mean_squared_error: 12.3723
# Epoch 14/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 67.4705 - root_mean_squared_error: 8.1604 - val_loss: 62.5439 - val_root_mean_squared_error: 7.8527
# Epoch 15/500
# 4947/4947 [==============================] - 37s 7ms/step - loss: 66.7692 - root_mean_squared_error: 8.1173 - val_loss: 180.2900 - val_root_mean_squared_error: 13.3944
# Epoch 16/500
# Epoch 50/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 56.7620 - root_mean_squared_error: 7.4753 - val_loss: 81.4480 - val_root_mean_squared_error: 8.9759
# Epoch 51/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 56.3396 - root_mean_squared_error: 7.4470 - val_loss: 88.4193 - val_root_mean_squared_error: 9.3561
# Epoch 52/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 56.7714 - root_mean_squared_error: 7.4760 - val_loss: 57.8769 - val_root_mean_squared_error: 7.5495
# Epoch 53/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 56.0527 - root_mean_squared_error: 7.4277 - val_loss: 166.7203 - val_root_mean_squared_error: 12.8778
# Epoch 54/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 55.8417 - root_mean_squared_error: 7.4136 - val_loss: 87.8329 - val_root_mean_squared_error: 9.3248
# Epoch 55/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 55.7613 - root_mean_squared_error: 7.4082 - val_loss: 78.0938 - val_root_mean_squared_error: 8.7871
# Epoch 56/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 55.6933 - root_mean_squared_error: 7.4036 - val_loss: 39.5514 - val_root_mean_squared_error: 6.2186
# Epoch 57/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 55.5197 - root_mean_squared_error: 7.3919 - val_loss: 40.5971 - val_root_mean_squared_error: 6.3022
# Epoch 58/500
# 4947/4947 [==============================] - 36s 7ms/step - loss: 55.1202 - root_mean_squared_error: 7.3648 - val_loss: 46.3772 - val_root_mean_squared_error: 6.7452
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 3781/3781 [==============================] - 9s 2ms/step - loss: 63.1134 - root_mean_squared_error: 7.8885

# %% [markdown]
# # Flight Class 3

# %%
# early stopping parameters
min_delta = 8
#min_delta = 
patience = 24

# compile parameters
#lr = .00005
lr = .000025

# fit parameters
batch_size = 64
epochs = 500


early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                               mode='min', 
                                               min_delta=min_delta, 
                                               patience=patience, 
                                               verbose=1,
                                               restore_best_weights=True)
model = make_model()

model.compile(loss='mse',
              optimizer=keras.optimizers.Adam(lr=lr),
              metrics=[keras.metrics.RootMeanSquaredError()])

model.summary()

history = model.fit(X_train3, y_train3, 
                    batch_size=batch_size, 
                    epochs=epochs,
                    validation_data=(X_val3, y_val3),
                    callbacks=[early_stopping])


fig = plt.figure(figsize=(9,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("loss")
plt.show()

fig = plt.figure(figsize=(9,6))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title("rmse")
plt.show()

model.evaluate(X_test3, y_test3, batch_size=32, verbose=1)

y_pred = model.predict(X_test3)

fig = plt.figure
plt.plot(y_test3.reshape(-1,1), label='true')
plt.plot(y_pred, label='pred')
plt.title("test results for flight class 3")
plt.xlabel("sample number")
plt.ylabel("rul")
plt.show()
# Out:
# C:\Users\lab\envs\tf2gpu\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# in1 (InputLayer)             [(None, 20, 28)]          0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 20, 28)            3948
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_27 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 20, 28)            2380
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 20, 28)            112
# _________________________________________________________________
# tf.nn.relu_28 (TFOpLambda)   (None, 20, 28)            0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 20, 1)             85
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 20, 1)             4
# _________________________________________________________________
# tf.nn.relu_29 (TFOpLambda)   (None, 20, 1)             0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                1344
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 8,050
# Trainable params: 7,936
# Non-trainable params: 114
# _________________________________________________________________
# Epoch 1/500
# 7155/7155 [==============================] - 53s 7ms/step - loss: 478.8015 - root_mean_squared_error: 21.8645 - val_loss: 268.0072 - val_root_mean_squared_error: 16.3502
# Epoch 2/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 122.4427 - root_mean_squared_error: 11.0322 - val_loss: 199.1044 - val_root_mean_squared_error: 14.0831
# Epoch 3/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 76.9633 - root_mean_squared_error: 8.7276 - val_loss: 90.7318 - val_root_mean_squared_error: 9.4826
# Epoch 4/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 67.3267 - root_mean_squared_error: 8.1546 - val_loss: 478.5899 - val_root_mean_squared_error: 21.8574
# Epoch 5/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 62.2397 - root_mean_squared_error: 7.8350 - val_loss: 140.7871 - val_root_mean_squared_error: 11.8289
# Epoch 6/500
# 7155/7155 [==============================] - 51s 7ms/step - loss: 58.6099 - root_mean_squared_error: 7.5987 - val_loss: 231.4120 - val_root_mean_squared_error: 15.1834
# Epoch 7/500
# 7155/7155 [==============================] - 51s 7ms/step - loss: 56.3880 - root_mean_squared_error: 7.4503 - val_loss: 288.5367 - val_root_mean_squared_error: 16.9603
# Epoch 8/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 54.9803 - root_mean_squared_error: 7.3547 - val_loss: 76.4324 - val_root_mean_squared_error: 8.6914
# Epoch 9/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 53.2863 - root_mean_squared_error: 7.2383 - val_loss: 138.4788 - val_root_mean_squared_error: 11.7296
# Epoch 10/500
# 7155/7155 [==============================] - 51s 7ms/step - loss: 51.9881 - root_mean_squared_error: 7.1479 - val_loss: 105.4843 - val_root_mean_squared_error: 10.2268
# Epoch 11/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 50.8619 - root_mean_squared_error: 7.0686 - val_loss: 64.0503 - val_root_mean_squared_error: 7.9470
# Epoch 12/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 41.2801 - root_mean_squared_error: 6.3597 - val_loss: 75.1360 - val_root_mean_squared_error: 8.6199
# Epoch 30/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 40.6136 - root_mean_squared_error: 6.3073 - val_loss: 51.5665 - val_root_mean_squared_error: 7.1229
# Epoch 31/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 40.4556 - root_mean_squared_error: 6.2950 - val_loss: 203.0562 - val_root_mean_squared_error: 14.2207
# Epoch 32/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 40.3305 - root_mean_squared_error: 6.2852 - val_loss: 88.7041 - val_root_mean_squared_error: 9.3743
# Epoch 33/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 39.8415 - root_mean_squared_error: 6.2463 - val_loss: 88.1447 - val_root_mean_squared_error: 9.3446
# Epoch 34/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 39.6727 - root_mean_squared_error: 6.2330 - val_loss: 245.5656 - val_root_mean_squared_error: 15.6443
# Epoch 35/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 39.3944 - root_mean_squared_error: 6.2107 - val_loss: 237.2424 - val_root_mean_squared_error: 15.3760
# Epoch 36/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 39.2544 - root_mean_squared_error: 6.1996 - val_loss: 154.9127 - val_root_mean_squared_error: 12.4135
# Epoch 37/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 39.1431 - root_mean_squared_error: 6.1907 - val_loss: 102.8154 - val_root_mean_squared_error: 10.0994
# Epoch 38/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 38.6364 - root_mean_squared_error: 6.1498 - val_loss: 106.9419 - val_root_mean_squared_error: 10.3018
# Epoch 39/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 38.5200 - root_mean_squared_error: 6.1404 - val_loss: 57.2258 - val_root_mean_squared_error: 7.5108
# Epoch 40/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 38.2952 - root_mean_squared_error: 6.1222 - val_loss: 295.9873 - val_root_mean_squared_error: 17.1806
# Epoch 41/500
# 7155/7155 [==============================] - 52s 7ms/step - loss: 37.8270 - root_mean_squared_error: 6.0840 - val_loss: 203.3451 - val_root_mean_squared_error: 14.2314
# Epoch 42/500
# 7155/7155 [==============================] - 51s 7ms/step - loss: 38.2230 - root_mean_squared_error: 6.1165 - val_loss: 78.8850 - val_root_mean_squared_error: 8.8360
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 5316/5316 [==============================] - 13s 2ms/step - loss: 120.8469 - root_mean_squared_error: 10.9531

# %% [markdown]
# ## Thoughts
# - split the sets up as we described and train a model on the linear portion and a separate model on the non linear portion
# - flight class 2 seemed to perform much better than 1 or 3, but also we should try multiple times with different unit splits
# - flight class 3 had one unit do really bad, and another unit do the best out of all
#
# # Tuesday
# - bilstm with residual connections using subclassing
#
#
# # Wednesday
# - custom loss and training functions

# %%
# Out:
# (39971, 1)
